# %%
#LGBM 결과 - 응답시간 제거 안 했을 때
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import warnings
import xgboost as xgb
warnings.filterwarnings('ignore')
# %matplotlib inline

from sklearn.preprocessing import OneHotEncoder
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from xgboost import plot_importance
from sklearn.datasets import load_breast_cancer
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

train2=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")

#zero_features = ['education', 'engnat', 'hand', 'married']

index = test['index']

pd.set_option('display.max_columns', 100)

Unneed_list = ['index']
train2.drop(Unneed_list, axis=1, inplace=True)
test.drop(Unneed_list, axis=1, inplace=True)


train3=pd.get_dummies(train2)
test=pd.get_dummies(test)


zero_features = ['education', 'engnat', 'hand', 'married']

#결손값(무응답 = 0)제거 함수
def drop_NoResponse(df):
    for col in zero_features:
        df.drop(df[df[col]==0].index, axis=0, inplace=True)
        
    return df
train = drop_NoResponse(train3)

max_index = train['familysize'].idxmax()
train.drop(max_index, axis=0, inplace=True)
#trainX에 투표값 제거
train_X = train.drop('voted', axis = 1)

#trainy에 투표값만 넣음
train_y = train['voted']


X_train, X_test, y_train, y_test=train_test_split(train_X, train_y, test_size=0.2, random_state=0)

lgbm_wrapper = LGBMClassifier(n_estimators=400)

evals = [(X_test, y_test)]
lgbm_wrapper.fit(X_train, y_train, early_stopping_rounds=100, eval_metric='logloss',
                eval_set=evals, verbose=True)
preds = lgbm_wrapper.predict(X_test)


def get_clf_eval(y_test, pred):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)
    print('오차행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}'.format(accuracy, precision, recall, f1))
    
get_clf_eval(y_test, preds)
#X_new = test
#X_new.shape
#new_pred_class = lgbm_wrapper.predict(X_new)
#new_pred_class.shape
#pred_proba = lgbm_wrapper.predict_proba(X_new)[:,1]
#sub = pd.DataFrame({'index':index, 'pred_prob':pred_proba, 'pred': new_pred_class})
#sub.set_index('index', inplace=True)
#sub.to_csv('lgbm_sum1.csv')
# Out:
# [1]	valid_0's binary_logloss: 0.668401
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's binary_logloss: 0.650933
# [3]	valid_0's binary_logloss: 0.636793
# [4]	valid_0's binary_logloss: 0.624798
# [5]	valid_0's binary_logloss: 0.614873
# [6]	valid_0's binary_logloss: 0.606332
# [7]	valid_0's binary_logloss: 0.599229
# [8]	valid_0's binary_logloss: 0.593076
# [9]	valid_0's binary_logloss: 0.587909
# [10]	valid_0's binary_logloss: 0.583227
# [11]	valid_0's binary_logloss: 0.579308
# [12]	valid_0's binary_logloss: 0.576041
# [13]	valid_0's binary_logloss: 0.573077
# [14]	valid_0's binary_logloss: 0.570422
# [15]	valid_0's binary_logloss: 0.56843
# [16]	valid_0's binary_logloss: 0.566526
# [17]	valid_0's binary_logloss: 0.564854
# [18]	valid_0's binary_logloss: 0.563422
# [19]	valid_0's binary_logloss: 0.562285
# [20]	valid_0's binary_logloss: 0.561232
# [21]	valid_0's binary_logloss: 0.560653
# [22]	valid_0's binary_logloss: 0.55969
# [23]	valid_0's binary_logloss: 0.559135
# [24]	valid_0's binary_logloss: 0.558422
# [25]	valid_0's binary_logloss: 0.557777
# [26]	valid_0's binary_logloss: 0.557365
# [27]	valid_0's binary_logloss: 0.557002
# [28]	valid_0's binary_logloss: 0.556685
# [29]	valid_0's binary_logloss: 0.556527
# [30]	valid_0's binary_logloss: 0.556083
# [31]	valid_0's binary_logloss: 0.556111
# [32]	valid_0's binary_logloss: 0.555591
# [33]	valid_0's binary_logloss: 0.555286
# [34]	valid_0's binary_logloss: 0.555065
# [35]	valid_0's binary_logloss: 0.555011
# [36]	valid_0's binary_logloss: 0.554728
# [37]	valid_0's binary_logloss: 0.554464
# [38]	valid_0's binary_logloss: 0.554408
# [39]	valid_0's binary_logloss: 0.554595
# [40]	valid_0's binary_logloss: 0.554476
# [41]	valid_0's binary_logloss: 0.554528
# [42]	valid_0's binary_logloss: 0.554682
# [43]	valid_0's binary_logloss: 0.554765
# [44]	valid_0's binary_logloss: 0.555047
# [45]	valid_0's binary_logloss: 0.55516
# [46]	valid_0's binary_logloss: 0.55505
# [47]	valid_0's binary_logloss: 0.555265
# [48]	valid_0's binary_logloss: 0.555271
# [49]	valid_0's binary_logloss: 0.555242
# [50]	valid_0's binary_logloss: 0.555354
# [51]	valid_0's binary_logloss: 0.555529
# [52]	valid_0's binary_logloss: 0.555619
# [53]	valid_0's binary_logloss: 0.555603
# [54]	valid_0's binary_logloss: 0.555688
# [55]	valid_0's binary_logloss: 0.55575
# [56]	valid_0's binary_logloss: 0.55579
# [57]	valid_0's binary_logloss: 0.555749
# [58]	valid_0's binary_logloss: 0.555742
# [59]	valid_0's binary_logloss: 0.555809
# [60]	valid_0's binary_logloss: 0.555465
# [61]	valid_0's binary_logloss: 0.555555
# [62]	valid_0's binary_logloss: 0.555526
# [63]	valid_0's binary_logloss: 0.555463
# [64]	valid_0's binary_logloss: 0.555634
# [65]	valid_0's binary_logloss: 0.555508
# [66]	valid_0's binary_logloss: 0.555487
# [67]	valid_0's binary_logloss: 0.555541
# [68]	valid_0's binary_logloss: 0.555449
# [69]	valid_0's binary_logloss: 0.555486
# [70]	valid_0's binary_logloss: 0.555578
# [71]	valid_0's binary_logloss: 0.555568
# [72]	valid_0's binary_logloss: 0.555531
# [73]	valid_0's binary_logloss: 0.555492
# [74]	valid_0's binary_logloss: 0.555426
# [75]	valid_0's binary_logloss: 0.555399
# [76]	valid_0's binary_logloss: 0.555467
# [77]	valid_0's binary_logloss: 0.555514
# [78]	valid_0's binary_logloss: 0.55554
# [79]	valid_0's binary_logloss: 0.555457
# [80]	valid_0's binary_logloss: 0.55547
# [81]	valid_0's binary_logloss: 0.555677
# [82]	valid_0's binary_logloss: 0.555975
# [83]	valid_0's binary_logloss: 0.556018
# [84]	valid_0's binary_logloss: 0.556019
# [85]	valid_0's binary_logloss: 0.55591
# [86]	valid_0's binary_logloss: 0.555959
# [87]	valid_0's binary_logloss: 0.556065
# [88]	valid_0's binary_logloss: 0.555987
# [89]	valid_0's binary_logloss: 0.556083
# [90]	valid_0's binary_logloss: 0.556084
# [91]	valid_0's binary_logloss: 0.556161
# [92]	valid_0's binary_logloss: 0.556135
# [93]	valid_0's binary_logloss: 0.55633
# [94]	valid_0's binary_logloss: 0.556419
# [95]	valid_0's binary_logloss: 0.556325
# [96]	valid_0's binary_logloss: 0.556471
# [97]	valid_0's binary_logloss: 0.55653
# [98]	valid_0's binary_logloss: 0.556714
# [99]	valid_0's binary_logloss: 0.556811
# [100]	valid_0's binary_logloss: 0.556946
# [101]	valid_0's binary_logloss: 0.557144
# [102]	valid_0's binary_logloss: 0.557043
# [103]	valid_0's binary_logloss: 0.557196
# [104]	valid_0's binary_logloss: 0.55724
# [105]	valid_0's binary_logloss: 0.557352
# [106]	valid_0's binary_logloss: 0.557429
# [107]	valid_0's binary_logloss: 0.557368
# [108]	valid_0's binary_logloss: 0.557347
# [109]	valid_0's binary_logloss: 0.557284
# [110]	valid_0's binary_logloss: 0.557273
# [111]	valid_0's binary_logloss: 0.557395
# [112]	valid_0's binary_logloss: 0.557695
# [113]	valid_0's binary_logloss: 0.557906
# [114]	valid_0's binary_logloss: 0.557994
# [115]	valid_0's binary_logloss: 0.558221
# [116]	valid_0's binary_logloss: 0.558371
# [117]	valid_0's binary_logloss: 0.558429
# [118]	valid_0's binary_logloss: 0.558712
# [119]	valid_0's binary_logloss: 0.558869
# [120]	valid_0's binary_logloss: 0.558943
# [121]	valid_0's binary_logloss: 0.558967
# [122]	valid_0's binary_logloss: 0.559085
# [123]	valid_0's binary_logloss: 0.559177
# [124]	valid_0's binary_logloss: 0.559193
# [125]	valid_0's binary_logloss: 0.55932
# [126]	valid_0's binary_logloss: 0.559458
# [127]	valid_0's binary_logloss: 0.559431
# [128]	valid_0's binary_logloss: 0.559369
# [129]	valid_0's binary_logloss: 0.559449
# [130]	valid_0's binary_logloss: 0.559428
# [131]	valid_0's binary_logloss: 0.559657
# [132]	valid_0's binary_logloss: 0.559903
# [133]	valid_0's binary_logloss: 0.559963
# [134]	valid_0's binary_logloss: 0.559978
# [135]	valid_0's binary_logloss: 0.560055
# [136]	valid_0's binary_logloss: 0.560128
# [137]	valid_0's binary_logloss: 0.560194
# [138]	valid_0's binary_logloss: 0.560263
# Early stopping, best iteration is:
# [38]	valid_0's binary_logloss: 0.554408
# 오차행렬
# [[2456 1434]
#  [ 676 2581]]
# 정확도: 0.7048, 정밀도: 0.6428, 재현율: 0.7924, F1: 0.7098

# %%
#LGBM 결과 - ['education', 'hand', 'married'] 제거했을 때
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import warnings
import xgboost as xgb
warnings.filterwarnings('ignore')
# %matplotlib inline

from sklearn.preprocessing import OneHotEncoder
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from xgboost import plot_importance
from sklearn.datasets import load_breast_cancer
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

train2=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")

#zero_features = ['education', 'engnat', 'hand', 'married']

index = test['index']

pd.set_option('display.max_columns', 100)

Unneed_list = ['QaE', 'QbE', 'QcE', 'QdE', 'QeE','QfE', 'QgE', 'QhE', 'QiE', 'QjE',
               'QkE', 'QlE', 'QmE', 'QnE', 'QoE','QpE', 'QqE', 'QrE', 'QsE', 'QtE', 'index']
train2.drop(Unneed_list, axis=1, inplace=True)
test.drop(Unneed_list, axis=1, inplace=True)


train3=pd.get_dummies(train2)
test=pd.get_dummies(test)


zero_features = ['education', 'hand', 'married']

#결손값(무응답 = 0)제거 함수
def drop_NoResponse(df):
    for col in zero_features:
        df.drop(df[df[col]==0].index, axis=0, inplace=True)
        
    return df
train = drop_NoResponse(train3)


max_index = train['familysize'].idxmax()
train.drop(max_index, axis=0, inplace=True)
#trainX에 투표값 제거
train_X = train.drop('voted', axis = 1)

#trainy에 투표값만 넣음
train_y = train['voted']


X_train, X_test, y_train, y_test=train_test_split(train_X, train_y, test_size=0.2, random_state=0)

lgbm_wrapper = LGBMClassifier(n_estimators=400)

evals = [(X_test, y_test)]
lgbm_wrapper.fit(X_train, y_train, early_stopping_rounds=100, eval_metric='logloss',
                eval_set=evals, verbose=True)
preds = lgbm_wrapper.predict(X_test)


def get_clf_eval(y_test, pred):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)
    print('오차행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}'.format(accuracy, precision, recall, f1))
    
get_clf_eval(y_test, preds)
#X_new = test
#X_new.shape
#new_pred_class = lgbm_wrapper.predict(X_new)
#new_pred_class.shape
#pred_proba = lgbm_wrapper.predict_proba(X_new)[:,1]
#sub = pd.DataFrame({'index':index, 'pred_prob':pred_proba, 'pred': new_pred_class})
#sub.set_index('index', inplace=True)
#sub.to_csv('lgbm_sum1.csv')
# Out:
# [1]	valid_0's binary_logloss: 0.668718
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's binary_logloss: 0.651571
# [3]	valid_0's binary_logloss: 0.637125
# [4]	valid_0's binary_logloss: 0.625103
# [5]	valid_0's binary_logloss: 0.614839
# [6]	valid_0's binary_logloss: 0.606329
# [7]	valid_0's binary_logloss: 0.599063
# [8]	valid_0's binary_logloss: 0.593045
# [9]	valid_0's binary_logloss: 0.587718
# [10]	valid_0's binary_logloss: 0.583287
# [11]	valid_0's binary_logloss: 0.579486
# [12]	valid_0's binary_logloss: 0.576173
# [13]	valid_0's binary_logloss: 0.573199
# [14]	valid_0's binary_logloss: 0.570675
# [15]	valid_0's binary_logloss: 0.568433
# [16]	valid_0's binary_logloss: 0.566694
# [17]	valid_0's binary_logloss: 0.565002
# [18]	valid_0's binary_logloss: 0.563241
# [19]	valid_0's binary_logloss: 0.562025
# [20]	valid_0's binary_logloss: 0.56071
# [21]	valid_0's binary_logloss: 0.559625
# [22]	valid_0's binary_logloss: 0.558605
# [23]	valid_0's binary_logloss: 0.55773
# [24]	valid_0's binary_logloss: 0.556973
# [25]	valid_0's binary_logloss: 0.556324
# [26]	valid_0's binary_logloss: 0.555899
# [27]	valid_0's binary_logloss: 0.555544
# [28]	valid_0's binary_logloss: 0.555212
# [29]	valid_0's binary_logloss: 0.554946
# [30]	valid_0's binary_logloss: 0.554507
# [31]	valid_0's binary_logloss: 0.554223
# [32]	valid_0's binary_logloss: 0.554055
# [33]	valid_0's binary_logloss: 0.553957
# [34]	valid_0's binary_logloss: 0.553953
# [35]	valid_0's binary_logloss: 0.553887
# [36]	valid_0's binary_logloss: 0.553684
# [37]	valid_0's binary_logloss: 0.553561
# [38]	valid_0's binary_logloss: 0.55348
# [39]	valid_0's binary_logloss: 0.553492
# [40]	valid_0's binary_logloss: 0.553417
# [41]	valid_0's binary_logloss: 0.553474
# [42]	valid_0's binary_logloss: 0.553484
# [43]	valid_0's binary_logloss: 0.553614
# [44]	valid_0's binary_logloss: 0.55351
# [45]	valid_0's binary_logloss: 0.55346
# [46]	valid_0's binary_logloss: 0.55343
# [47]	valid_0's binary_logloss: 0.55354
# [48]	valid_0's binary_logloss: 0.553488
# [49]	valid_0's binary_logloss: 0.553549
# [50]	valid_0's binary_logloss: 0.553622
# [51]	valid_0's binary_logloss: 0.553693
# [52]	valid_0's binary_logloss: 0.553576
# [53]	valid_0's binary_logloss: 0.553554
# [54]	valid_0's binary_logloss: 0.553593
# [55]	valid_0's binary_logloss: 0.553711
# [56]	valid_0's binary_logloss: 0.553842
# [57]	valid_0's binary_logloss: 0.553755
# [58]	valid_0's binary_logloss: 0.553699
# [59]	valid_0's binary_logloss: 0.553658
# [60]	valid_0's binary_logloss: 0.553656
# [61]	valid_0's binary_logloss: 0.55382
# [62]	valid_0's binary_logloss: 0.553834
# [63]	valid_0's binary_logloss: 0.553811
# [64]	valid_0's binary_logloss: 0.553784
# [65]	valid_0's binary_logloss: 0.553795
# [66]	valid_0's binary_logloss: 0.55392
# [67]	valid_0's binary_logloss: 0.553869
# [68]	valid_0's binary_logloss: 0.553739
# [69]	valid_0's binary_logloss: 0.553723
# [70]	valid_0's binary_logloss: 0.553683
# [71]	valid_0's binary_logloss: 0.553606
# [72]	valid_0's binary_logloss: 0.553646
# [73]	valid_0's binary_logloss: 0.553746
# [74]	valid_0's binary_logloss: 0.553871
# [75]	valid_0's binary_logloss: 0.553931
# [76]	valid_0's binary_logloss: 0.55415
# [77]	valid_0's binary_logloss: 0.554237
# [78]	valid_0's binary_logloss: 0.554367
# [79]	valid_0's binary_logloss: 0.554383
# [80]	valid_0's binary_logloss: 0.554385
# [81]	valid_0's binary_logloss: 0.554391
# [82]	valid_0's binary_logloss: 0.55443
# [83]	valid_0's binary_logloss: 0.554484
# [84]	valid_0's binary_logloss: 0.554443
# [85]	valid_0's binary_logloss: 0.554387
# [86]	valid_0's binary_logloss: 0.554493
# [87]	valid_0's binary_logloss: 0.55449
# [88]	valid_0's binary_logloss: 0.554517
# [89]	valid_0's binary_logloss: 0.554624
# [90]	valid_0's binary_logloss: 0.554622
# [91]	valid_0's binary_logloss: 0.554668
# [92]	valid_0's binary_logloss: 0.554741
# [93]	valid_0's binary_logloss: 0.554831
# [94]	valid_0's binary_logloss: 0.554946
# [95]	valid_0's binary_logloss: 0.554909
# [96]	valid_0's binary_logloss: 0.555029
# [97]	valid_0's binary_logloss: 0.555215
# [98]	valid_0's binary_logloss: 0.55532
# [99]	valid_0's binary_logloss: 0.555177
# [100]	valid_0's binary_logloss: 0.555196
# [101]	valid_0's binary_logloss: 0.555292
# [102]	valid_0's binary_logloss: 0.55533
# [103]	valid_0's binary_logloss: 0.55524
# [104]	valid_0's binary_logloss: 0.555381
# [105]	valid_0's binary_logloss: 0.555271
# [106]	valid_0's binary_logloss: 0.555258
# [107]	valid_0's binary_logloss: 0.555312
# [108]	valid_0's binary_logloss: 0.555252
# [109]	valid_0's binary_logloss: 0.555285
# [110]	valid_0's binary_logloss: 0.555342
# [111]	valid_0's binary_logloss: 0.55545
# [112]	valid_0's binary_logloss: 0.555467
# [113]	valid_0's binary_logloss: 0.555306
# [114]	valid_0's binary_logloss: 0.555224
# [115]	valid_0's binary_logloss: 0.555247
# [116]	valid_0's binary_logloss: 0.555235
# [117]	valid_0's binary_logloss: 0.55514
# [118]	valid_0's binary_logloss: 0.555312
# [119]	valid_0's binary_logloss: 0.555266
# [120]	valid_0's binary_logloss: 0.555177
# [121]	valid_0's binary_logloss: 0.555205
# [122]	valid_0's binary_logloss: 0.555336
# [123]	valid_0's binary_logloss: 0.555323
# [124]	valid_0's binary_logloss: 0.555477
# [125]	valid_0's binary_logloss: 0.555438
# [126]	valid_0's binary_logloss: 0.555522
# [127]	valid_0's binary_logloss: 0.555585
# [128]	valid_0's binary_logloss: 0.55554
# [129]	valid_0's binary_logloss: 0.555581
# [130]	valid_0's binary_logloss: 0.555572
# [131]	valid_0's binary_logloss: 0.555709
# [132]	valid_0's binary_logloss: 0.555844
# [133]	valid_0's binary_logloss: 0.555849
# [134]	valid_0's binary_logloss: 0.555919
# [135]	valid_0's binary_logloss: 0.555997
# [136]	valid_0's binary_logloss: 0.556027
# [137]	valid_0's binary_logloss: 0.556069
# [138]	valid_0's binary_logloss: 0.556052
# [139]	valid_0's binary_logloss: 0.556127
# [140]	valid_0's binary_logloss: 0.556029
# Early stopping, best iteration is:
# [40]	valid_0's binary_logloss: 0.553417
# 오차행렬
# [[2457 1418]
#  [ 685 2599]]
# 정확도: 0.7062, 정밀도: 0.6470, 재현율: 0.7914, F1: 0.7120
